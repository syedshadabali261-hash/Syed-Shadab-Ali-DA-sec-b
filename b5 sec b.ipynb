# %%
hello world
# Out:
#   Cell In[1], line 1
#     hello world
#           ^
# SyntaxError: invalid syntax

# %%
"hello world"
# Out:
# 'hello world'

# %%
print ("hello world")
# Out:
# hello world

# %%
123
# Out:
# 123

# %%
"123"
# Out:
# '123'

# %%
type (123)
# Out:
# int

# %%
type (12.34)
# Out:
# float

# %%
type ("123")
# Out:
# str
